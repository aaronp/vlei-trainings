// %% [markdown]
// simplified version of the vLEI ecosystem trust chain.
//
// We present here a simplified version of the vLEI trust chain. Using the real schema definitions, but simplifying the structure of the Identifiers. The production version relies on multisig and AID delegation. These examples simplify that part. To see how the chain is constructed, see [link to wvi_workflow repo]

// %% [markdown]
// ## Setup Phase
// Creates 4 different identity clients: GLEIF, QVI, LE, and Role
// Establishes connections between all parties
//
// Creates credential registries for issuers

// %%
import { randomPasscode, Saider, Serder} from 'npm:signify-ts@0.3.0-rc1';
import { initializeSignify, 
         initializeAndConnectClient,
         createNewAID,
         addEndRoleForAID,
         generateOOBI,
         resolveOOBI,
         createTimestamp,
         createCredentialRegistry,
         getSchema,
         issueCredential,
         ipexGrantCredential,
         getCredentialState,
         waitForAndGetNotification,
         ipexAdmitGrant,
         markNotificationRead,
         DEFAULT_IDENTIFIER_ARGS,
         DEFAULT_TIMEOUT_MS,
         DEFAULT_DELAY_MS,
         DEFAULT_RETRIES,
         ROLE_AGENT,
         IPEX_GRANT_ROUTE,
         IPEX_ADMIT_ROUTE,
         IPEX_APPLY_ROUTE,
         IPEX_OFFER_ROUTE,
         SCHEMA_SERVER_HOST
       } from './scripts_ts/utils.ts';

// Create clients, AIDs and OOBIs.

const gleifBran = randomPasscode()
const gleifAlias = 'gleif'
const { client: gleifClient } = await initializeAndConnectClient(gleifBran)
const { aid: gleifAid} = await createNewAID(gleifClient, gleifAlias, DEFAULT_IDENTIFIER_ARGS);
await addEndRoleForAID(gleifClient, gleifAlias, ROLE_AGENT);
const gleifOOBI = await generateOOBI(gleifClient, gleifAlias, ROLE_AGENT);

const qviBran = randomPasscode()
const qviAlias = 'qvi'
const { client: qviClient } = await initializeAndConnectClient(qviBran)
const { aid: qviAid} = await createNewAID(qviClient, qviAlias, DEFAULT_IDENTIFIER_ARGS);
await addEndRoleForAID(qviClient, qviAlias, ROLE_AGENT);
const qviOOBI = await generateOOBI(qviClient, qviAlias, ROLE_AGENT);

const leBran = randomPasscode()
const leAlias = 'le'
const { client: leClient } = await initializeAndConnectClient(leBran)
const { aid: leAid} = await createNewAID(leClient, leAlias, DEFAULT_IDENTIFIER_ARGS);
await addEndRoleForAID(leClient, leAlias, ROLE_AGENT);
const leOOBI = await generateOOBI(leClient, leAlias, ROLE_AGENT);

const roleBran = randomPasscode()
const roleAlias = 'role'
const { client: roleClient } = await initializeAndConnectClient(roleBran)
const { aid: roleAid} = await createNewAID(roleClient, roleAlias, DEFAULT_IDENTIFIER_ARGS);
await addEndRoleForAID(roleClient, roleAlias, ROLE_AGENT);
const roleOOBI = await generateOOBI(roleClient, roleAlias, ROLE_AGENT);


// Client OOBI resolution (Create contacts)
await Promise.all([
    resolveOOBI(gleifClient, qviOOBI, qviAlias),
    resolveOOBI(qviClient, gleifOOBI, gleifAlias),
    resolveOOBI(qviClient, leOOBI, leAlias),
    resolveOOBI(qviClient, roleOOBI, roleAlias),
    resolveOOBI(leClient, gleifOOBI, gleifAlias),
    resolveOOBI(leClient, qviOOBI, qviAlias),
    resolveOOBI(leClient, roleOOBI, roleAlias),
    resolveOOBI(roleClient, gleifOOBI, gleifAlias),
    resolveOOBI(roleClient, leOOBI, leAlias),
    resolveOOBI(roleClient, qviOOBI, qviAlias)
]);

// Create Issuer Credential Registry


const { registrySaid: gleifRegistrySaid } = await createCredentialRegistry(gleifClient, gleifAlias, 'gleifRegistry')
const { registrySaid: qviRegistrySaid } = createCredentialRegistry(qviClient, qviAlias, 'qviRegistry')
const { registrySaid: leRegistrySaid } = createCredentialRegistry(leClient, leAlias, 'leRegistry')
// Out:
// Using Passcode (bran): BqoaJc5uPDqKVnmAWPgBt
// Client boot process initiated with KERIA agent.
//   Client AID Prefix:  EAVZ2wSunSvjss_JPSbUIgZW6C48PrQ78zrwYh5V-fJd
//   Agent AID Prefix:   EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ
// Initiating AID inception for alias: gleif
// Successfully created AID with prefix: EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt
// Assigning 'agent' role to KERIA Agent EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ for AID alias gleif
// Successfully assigned 'agent' role for AID alias gleif.
// Generating OOBI for AID alias gleif with role agent
// Generated OOBI URL: http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ
// Using Passcode (bran): D0zjYJMaX_waCgpU7jbOV
// Client boot process initiated with KERIA agent.
//   Client AID Prefix:  ED-DHukbbwy8gNde17QbRfLzPI53I9YvJFVrOKsXMZHU
//   Agent AID Prefix:   EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq
// Initiating AID inception for alias: qvi
// Successfully created AID with prefix: EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL
// Assigning 'agent' role to KERIA Agent EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq for AID alias qvi
// Successfully assigned 'agent' role for AID alias qvi.
// Generating OOBI for AID alias qvi with role agent
// Generated OOBI URL: http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq
// Using Passcode (bran): Ae84xRiBfGNq14N0yTCej
// Client boot process initiated with KERIA agent.
//   Client AID Prefix:  EINU50p-qmNcJaCAsqe5DqcugOIvDxco9yO5l90Ridlq
//   Agent AID Prefix:   EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW
// Initiating AID inception for alias: le
// Successfully created AID with prefix: ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8
// Assigning 'agent' role to KERIA Agent EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW for AID alias le
// Successfully assigned 'agent' role for AID alias le.
// Generating OOBI for AID alias le with role agent
// Generated OOBI URL: http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW
// Using Passcode (bran): A_qkBpOE5Ur1KDmRFX6KH
// Client boot process initiated with KERIA agent.
//   Client AID Prefix:  EJcijULvEskcev3y_Y48MLBI25YEaSZH0StfvlKmU4J3
//   Agent AID Prefix:   EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L
// Initiating AID inception for alias: role
// Successfully created AID with prefix: EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw
// Assigning 'agent' role to KERIA Agent EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L for AID alias role
// Successfully assigned 'agent' role for AID alias role.
// Generating OOBI for AID alias role with role agent
// Generated OOBI URL: http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L
// Resolving OOBI URL: http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq with alias qvi
// Resolving OOBI URL: http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ with alias gleif
// Resolving OOBI URL: http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW with alias le
// Resolving OOBI URL: http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L with alias role
// Resolving OOBI URL: http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ with alias gleif
// Resolving OOBI URL: http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq with alias qvi
// Resolving OOBI URL: http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L with alias role
// Resolving OOBI URL: http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ with alias gleif
// Resolving OOBI URL: http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW with alias le
// Resolving OOBI URL: http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq with alias qvi
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Contact "le" added/updated.
// Contact "qvi" added/updated.
// Contact "gleif" added/updated.
// Contact "role" added/updated.
// Contact "role" added/updated.
// Contact "le" added/updated.
// Contact "qvi" added/updated.
// Contact "gleif" added/updated.
// Contact "qvi" added/updated.
// Contact "gleif" added/updated.
// Creating credential registry "gleifRegistry" for AID alias "gleif"...
// Successfully created credential registry: EAkkDRthKw0cPvMvFbMI_hpRiqL2Qp5kBMGsRvyT_dav
// Creating credential registry "qviRegistry" for AID alias "qvi"...
// Creating credential registry "leRegistry" for AID alias "le"...
// [
//   {
//     operation: {
//       name: "oobi.0AA6DWzKEN2q3yJvSlykeO07",
//       metadata: {
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq"
//       },
//       done: true,
//       error: null,
//       response: {
//         vn: [ 1, 0 ],
//         i: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         s: "0",
//         p: "",
//         d: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         f: "0",
//         dt: "2025-06-12T21:58:55.049505+00:00",
//         et: "icp",
//         kt: "1",
//         k: [ "DArwLqrtw3iJWA7InUsF4_We9hCn2YT38ScB8TQ_4nSw" ],
//         nt: "1",
//         n: [ "EJLr9y3GL2wv_PlKNUwLoicCY5uAWY1aizB8HhI-zHK0" ],
//         bt: "3",
//         b: [
//           "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//           "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//           "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX"
//         ],
//         c: [],
//         ee: {
//           s: "0",
//           d: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//           br: [],
//           ba: []
//         },
//         di: ""
//       }
//     },
//     contact: [
//       {
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ACxsFIu8LoEXP0GCjx51nR3",
//       metadata: {
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ"
//       },
//       done: true,
//       error: null,
//       response: {
//         vn: [ 1, 0 ],
//         i: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         s: "0",
//         p: "",
//         d: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         f: "0",
//         dt: "2025-06-12T21:58:55.109236+00:00",
//         et: "icp",
//         kt: "1",
//         k: [ "DAEXuis_BbgTKPyZho9y6SekrYvg3sITZXHOiSEanlRF" ],
//         nt: "1",
//         n: [ "EHKlTc0XkLccOsM14MFtXM2feh_fX4tinX4tgoU589CJ" ],
//         bt: "3",
//         b: [
//           "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//           "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//           "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX"
//         ],
//         c: [],
//         ee: {
//           s: "0",
//           d: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//           br: [],
//           ba: []
//         },
//         di: ""
//       }
//     },
//     contact: [
//       {
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0AA-ATGKir6AGwfSTY8huPw2",
//       metadata: {
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW"
//       },
//       done: true,
//       error: null,
//       response: {
//         vn: [ 1, 0 ],
//         i: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         s: "0",
//         p: "",
//         d: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         f: "0",
//         dt: "2025-06-12T21:58:55.259209+00:00",
//         et: "icp",
//         kt: "1",
//         k: [ "DEH72Nfk2_exQ8BPTpbtzg9qLvGxUoI8jGuXEDjgIkal" ],
//         nt: "1",
//         n: [ "EOpKmgRZLHiGaiatWgKZRENY4HHrK_JsFCKpCEt8HslD" ],
//         bt: "3",
//         b: [
//           "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//           "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//           "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX"
//         ],
//         c: [],
//         ee: {
//           s: "0",
//           d: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//           br: [],
//           ba: []
//         },
//         di: ""
//       }
//     },
//     contact: [
//       {
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ACZCi7ZOcGgHTw29Fz4PmKb",
//       metadata: {
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L"
//       },
//       done: true,
//       error: null,
//       response: {
//         vn: [ 1, 0 ],
//         i: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         s: "0",
//         p: "",
//         d: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         f: "0",
//         dt: "2025-06-12T21:58:55.168888+00:00",
//         et: "icp",
//         kt: "1",
//         k: [ "DIakJrS8H5FdQ9uEUlC90wpeoLdFIDmO8fKtgdcVwo97" ],
//         nt: "1",
//         n: [ "ECtpp6C-f0oab0dpNAJEdQyBin97rkobwrokoNXRzTmC" ],
//         bt: "3",
//         b: [
//           "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//           "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//           "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX"
//         ],
//         c: [],
//         ee: {
//           s: "0",
//           d: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//           br: [],
//           ba: []
//         },
//         di: ""
//       }
//     },
//     contact: [
//       {
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ACrzqkuHnKDyozDCTiHQ0Vn",
//       metadata: {
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ"
//       },
//       done: true,
//       error: null,
//       response: {
//         vn: [ 1, 0 ],
//         i: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         s: "0",
//         p: "",
//         d: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         f: "0",
//         dt: "2025-06-12T21:58:55.361947+00:00",
//         et: "icp",
//         kt: "1",
//         k: [ "DAEXuis_BbgTKPyZho9y6SekrYvg3sITZXHOiSEanlRF" ],
//         nt: "1",
//         n: [ "EHKlTc0XkLccOsM14MFtXM2feh_fX4tinX4tgoU589CJ" ],
//         bt: "3",
//         b: [
//           "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//           "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//           "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX"
//         ],
//         c: [],
//         ee: {
//           s: "0",
//           d: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//           br: [],
//           ba: []
//         },
//         di: ""
//       }
//     },
//     contact: [
//       {
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ADH-JtAciklP_0yNhdpjgWB",
//       metadata: {
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq"
//       },
//       done: true,
//       error: null,
//       response: {
//         vn: [ 1, 0 ],
//         i: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         s: "0",
//         p: "",
//         d: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         f: "0",
//         dt: "2025-06-12T21:58:55.495491+00:00",
//         et: "icp",
//         kt: "1",
//         k: [ "DArwLqrtw3iJWA7InUsF4_We9hCn2YT38ScB8TQ_4nSw" ],
//         nt: "1",
//         n: [ "EJLr9y3GL2wv_PlKNUwLoicCY5uAWY1aizB8HhI-zHK0" ],
//         bt: "3",
//         b: [
//           "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//           "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//           "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX"
//         ],
//         c: [],
//         ee: {
//           s: "0",
//           d: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//           br: [],
//           ba: []
//         },
//         di: ""
//       }
//     },
//     contact: [
//       {
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0AD0zMiufX4OVAif8y92SXNb",
//       metadata: {
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L"
//       },
//       done: true,
//       error: null,
//       response: {
//         vn: [ 1, 0 ],
//         i: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         s: "0",
//         p: "",
//         d: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         f: "0",
//         dt: "2025-06-12T21:58:55.420696+00:00",
//         et: "icp",
//         kt: "1",
//         k: [ "DIakJrS8H5FdQ9uEUlC90wpeoLdFIDmO8fKtgdcVwo97" ],
//         nt: "1",
//         n: [ "ECtpp6C-f0oab0dpNAJEdQyBin97rkobwrokoNXRzTmC" ],
//         bt: "3",
//         b: [
//           "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//           "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//           "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX"
//         ],
//         c: [],
//         ee: {
//           s: "0",
//           d: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//           br: [],
//           ba: []
//         },
//         di: ""
//       }
//     },
//     contact: [
//       {
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0AAGV-hjRd1iulxdO_toBHGs",
//       metadata: {
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ"
//       },
//       done: true,
//       error: null,
//       response: {
//         vn: [ 1, 0 ],
//         i: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         s: "0",
//         p: "",
//         d: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         f: "0",
//         dt: "2025-06-12T21:58:55.598542+00:00",
//         et: "icp",
//         kt: "1",
//         k: [ "DAEXuis_BbgTKPyZho9y6SekrYvg3sITZXHOiSEanlRF" ],
//         nt: "1",
//         n: [ "EHKlTc0XkLccOsM14MFtXM2feh_fX4tinX4tgoU589CJ" ],
//         bt: "3",
//         b: [
//           "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//           "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//           "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX"
//         ],
//         c: [],
//         ee: {
//           s: "0",
//           d: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//           br: [],
//           ba: []
//         },
//         di: ""
//       }
//     },
//     contact: [
//       {
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ADlxuJukrdlvtzB_S4K8-im",
//       metadata: {
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW"
//       },
//       done: true,
//       error: null,
//       response: {
//         vn: [ 1, 0 ],
//         i: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         s: "0",
//         p: "",
//         d: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         f: "0",
//         dt: "2025-06-12T21:58:55.747931+00:00",
//         et: "icp",
//         kt: "1",
//         k: [ "DEH72Nfk2_exQ8BPTpbtzg9qLvGxUoI8jGuXEDjgIkal" ],
//         nt: "1",
//         n: [ "EOpKmgRZLHiGaiatWgKZRENY4HHrK_JsFCKpCEt8HslD" ],
//         bt: "3",
//         b: [
//           "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//           "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//           "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX"
//         ],
//         c: [],
//         ee: {
//           s: "0",
//           d: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//           br: [],
//           ba: []
//         },
//         di: ""
//       }
//     },
//     contact: [
//       {
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ACWIRRWqb-WZdgIM8NP-u1o",
//       metadata: {
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq"
//       },
//       done: true,
//       error: null,
//       response: {
//         vn: [ 1, 0 ],
//         i: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         s: "0",
//         p: "",
//         d: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         f: "0",
//         dt: "2025-06-12T21:58:55.661615+00:00",
//         et: "icp",
//         kt: "1",
//         k: [ "DArwLqrtw3iJWA7InUsF4_We9hCn2YT38ScB8TQ_4nSw" ],
//         nt: "1",
//         n: [ "EJLr9y3GL2wv_PlKNUwLoicCY5uAWY1aizB8HhI-zHK0" ],
//         bt: "3",
//         b: [
//           "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//           "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//           "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX"
//         ],
//         c: [],
//         ee: {
//           s: "0",
//           d: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//           br: [],
//           ba: []
//         },
//         di: ""
//       }
//     },
//     contact: [
//       {
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   }
// ]

// %% [markdown]
// Resolves schema definitions for different credential types
//
// Talk about the different schemas and list them:
//
// - **[QVI Credential](config/schemas/qualified-vLEI-issuer-vLEI-credential.json)**
// - **[vLEI Credential](config/schemas/legal-entity-vLEI-credential.json)**
// - **[OOR Auth Credential](config/schemas/oor-authorization-vLEI-credential.json)**
// - **[ECR Auth Credential](config/schemas/ecr-authorization-vlei-credential.json)**
// - **[OOR Credential](config/schemas/legal-entity-official-organizational-role-vLEI-credential.json)**
// - **[ECR Credential](config/schemas/legal-entity-engagement-context-role-vLEI-credential.json)**
//
//
//
// note: Schemas are preloaded

// %%
// Schemas

// vLEI Schema SAIDs. These are well known schemas. Already preloaded
const QVI_SCHEMA_SAID = 'EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao';
const LE_SCHEMA_SAID = 'ENPXp1vQzRF6JwIuS-mp2U8Uf1MoADoP_GqQ62VsDZWY';
const ECR_AUTH_SCHEMA_SAID = 'EH6ekLjSr8V32WyFbGe1zXjTzFs9PkTYmupJ9H65O14g';
const ECR_SCHEMA_SAID = 'EEy9PkikFcANV1l7EHukCeXqrzT1hNZjGlUk7wuMO5jw';
const OOR_AUTH_SCHEMA_SAID = 'EKA57bKBKxr_kN7iN5i7lMUxpMG-s19dRcmov1iDxz-E';
const OOR_SCHEMA_SAID = 'EBNaNu-M9P5cgrnfl2Fvymy4E_jvxxyjb70PRtiANlJy';

const schemaServer = `http://vlei-server:7723/oobi`;
const QVI_SCHEMA_URL = `${schemaServer}/${QVI_SCHEMA_SAID}`;
const LE_SCHEMA_URL = `${schemaServer}/${LE_SCHEMA_SAID}`;
const ECR_AUTH_SCHEMA_URL = `${schemaServer}/${ECR_AUTH_SCHEMA_SAID}`;
const ECR_SCHEMA_URL = `${schemaServer}/${ECR_SCHEMA_SAID}`;
const OOR_AUTH_SCHEMA_URL = `${schemaServer}/${OOR_AUTH_SCHEMA_SAID}`;
const OOR_SCHEMA_URL = `${schemaServer}/${OOR_SCHEMA_SAID}`;

// %% [markdown]
// Resolving schemas

// %%
await Promise.all([
    resolveOOBI(gleifClient, QVI_SCHEMA_URL),
    
    resolveOOBI(qviClient, QVI_SCHEMA_URL),
    resolveOOBI(qviClient, LE_SCHEMA_URL),
    resolveOOBI(qviClient, ECR_AUTH_SCHEMA_URL),
    resolveOOBI(qviClient, ECR_SCHEMA_URL),
    resolveOOBI(qviClient, OOR_AUTH_SCHEMA_URL),
    resolveOOBI(qviClient, OOR_SCHEMA_URL),
    
    resolveOOBI(leClient, QVI_SCHEMA_URL),
    resolveOOBI(leClient, LE_SCHEMA_URL),
    resolveOOBI(leClient, ECR_AUTH_SCHEMA_URL),
    resolveOOBI(leClient, ECR_SCHEMA_URL),
    resolveOOBI(leClient, OOR_AUTH_SCHEMA_URL),
    resolveOOBI(leClient, OOR_SCHEMA_URL),
    
    resolveOOBI(roleClient, QVI_SCHEMA_URL),
    resolveOOBI(roleClient, LE_SCHEMA_URL),
    resolveOOBI(roleClient, ECR_AUTH_SCHEMA_URL),
    resolveOOBI(roleClient, ECR_SCHEMA_URL),
    resolveOOBI(roleClient, OOR_AUTH_SCHEMA_URL),
    resolveOOBI(roleClient, OOR_SCHEMA_URL),
]);
// Out:
// Resolving OOBI URL: http://vlei-server:7723/oobi/EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/ENPXp1vQzRF6JwIuS-mp2U8Uf1MoADoP_GqQ62VsDZWY with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EH6ekLjSr8V32WyFbGe1zXjTzFs9PkTYmupJ9H65O14g with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EEy9PkikFcANV1l7EHukCeXqrzT1hNZjGlUk7wuMO5jw with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EKA57bKBKxr_kN7iN5i7lMUxpMG-s19dRcmov1iDxz-E with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EBNaNu-M9P5cgrnfl2Fvymy4E_jvxxyjb70PRtiANlJy with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/ENPXp1vQzRF6JwIuS-mp2U8Uf1MoADoP_GqQ62VsDZWY with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EH6ekLjSr8V32WyFbGe1zXjTzFs9PkTYmupJ9H65O14g with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EEy9PkikFcANV1l7EHukCeXqrzT1hNZjGlUk7wuMO5jw with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EKA57bKBKxr_kN7iN5i7lMUxpMG-s19dRcmov1iDxz-E with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EBNaNu-M9P5cgrnfl2Fvymy4E_jvxxyjb70PRtiANlJy with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/ENPXp1vQzRF6JwIuS-mp2U8Uf1MoADoP_GqQ62VsDZWY with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EH6ekLjSr8V32WyFbGe1zXjTzFs9PkTYmupJ9H65O14g with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EEy9PkikFcANV1l7EHukCeXqrzT1hNZjGlUk7wuMO5jw with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EKA57bKBKxr_kN7iN5i7lMUxpMG-s19dRcmov1iDxz-E with alias undefined
// Resolving OOBI URL: http://vlei-server:7723/oobi/EBNaNu-M9P5cgrnfl2Fvymy4E_jvxxyjb70PRtiANlJy with alias undefined
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Successfully resolved OOBI URL. Response: OK
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// Contact "undefined" added/updated.
// [
//   {
//     operation: {
//       name: "oobi.0ACdX_4vgyiogMwPTQaQiAhJ",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ADG53en4-4j_ui3FQX9N9sI",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ACxdx5eVcyCeKGu177paxSr",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/ENPXp1vQzRF6JwIuS-mp2U8Uf1MoADoP_GqQ62VsDZWY"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/ENPXp1vQzRF6JwIuS-mp2U8Uf1MoADoP_GqQ62VsDZWY"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ABr1S5272T5ATHFsTsGnf0E",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EH6ekLjSr8V32WyFbGe1zXjTzFs9PkTYmupJ9H65O14g"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EH6ekLjSr8V32WyFbGe1zXjTzFs9PkTYmupJ9H65O14g"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ABesOYcfWpzChAzcxq4hgvk",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EEy9PkikFcANV1l7EHukCeXqrzT1hNZjGlUk7wuMO5jw"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EEy9PkikFcANV1l7EHukCeXqrzT1hNZjGlUk7wuMO5jw"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ACZYRPsmCeZ0sMhdUhchCWE",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EKA57bKBKxr_kN7iN5i7lMUxpMG-s19dRcmov1iDxz-E"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EKA57bKBKxr_kN7iN5i7lMUxpMG-s19dRcmov1iDxz-E"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ADqk1bFRNtfunFK_0fDdr5n",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EBNaNu-M9P5cgrnfl2Fvymy4E_jvxxyjb70PRtiANlJy"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EBNaNu-M9P5cgrnfl2Fvymy4E_jvxxyjb70PRtiANlJy"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0AAXwVwhu4aztF1V1F6K-5Ob",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0AAzbTZnEFRPYprMJsj1eXHw",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/ENPXp1vQzRF6JwIuS-mp2U8Uf1MoADoP_GqQ62VsDZWY"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/ENPXp1vQzRF6JwIuS-mp2U8Uf1MoADoP_GqQ62VsDZWY"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ADcjDqxtYzULg7gJMGGXXM2",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EH6ekLjSr8V32WyFbGe1zXjTzFs9PkTYmupJ9H65O14g"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EH6ekLjSr8V32WyFbGe1zXjTzFs9PkTYmupJ9H65O14g"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ACsN0RFb3wRCyeYW2bpdLFj",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EEy9PkikFcANV1l7EHukCeXqrzT1hNZjGlUk7wuMO5jw"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EEy9PkikFcANV1l7EHukCeXqrzT1hNZjGlUk7wuMO5jw"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ABALYKZVSbGIQse0nFp-awc",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EKA57bKBKxr_kN7iN5i7lMUxpMG-s19dRcmov1iDxz-E"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EKA57bKBKxr_kN7iN5i7lMUxpMG-s19dRcmov1iDxz-E"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ABR2C4CtMwSWOzvGtEVc6y7",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EBNaNu-M9P5cgrnfl2Fvymy4E_jvxxyjb70PRtiANlJy"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EBNaNu-M9P5cgrnfl2Fvymy4E_jvxxyjb70PRtiANlJy"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw",
//         alias: "role",
//         oobi: "http://keria:3902/oobi/EFie7pOPsXpcZiV90Hg7D9Kob5Ciy1ByMFdSojHtExAw/agent/EEFpIVFWeFH9ZNLleusSC8hcKae_JSVTiRhwQ4olNa1L",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ABBNspRzfAgX4I-D7TG7n9B",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
// ...
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ABaMULAMtkYK_JZhisPSOeK",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EH6ekLjSr8V32WyFbGe1zXjTzFs9PkTYmupJ9H65O14g"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EH6ekLjSr8V32WyFbGe1zXjTzFs9PkTYmupJ9H65O14g"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0ACkPuWltAvA61ViDDC6uk-f",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EEy9PkikFcANV1l7EHukCeXqrzT1hNZjGlUk7wuMO5jw"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EEy9PkikFcANV1l7EHukCeXqrzT1hNZjGlUk7wuMO5jw"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0AANK4hCpKDkYJ18KgYXoDu-",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EKA57bKBKxr_kN7iN5i7lMUxpMG-s19dRcmov1iDxz-E"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EKA57bKBKxr_kN7iN5i7lMUxpMG-s19dRcmov1iDxz-E"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   },
//   {
//     operation: {
//       name: "oobi.0AABp_DwTfGoVvDSj_ghsnuQ",
//       metadata: {
//         oobi: "http://vlei-server:7723/oobi/EBNaNu-M9P5cgrnfl2Fvymy4E_jvxxyjb70PRtiANlJy"
//       },
//       done: true,
//       error: null,
//       response: {
//         oobi: "http://vlei-server:7723/oobi/EBNaNu-M9P5cgrnfl2Fvymy4E_jvxxyjb70PRtiANlJy"
//       }
//     },
//     contact: [
//       {
//         id: "BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha",
//         alias: "wan",
//         oobi: "http://witness-demo:5642/oobi/BBilc4-L3tFUnfM_wJr4S4OJanAv_VmF_dJNN6vkf2Ha/controller?name=wan&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM",
//         alias: "wyz",
//         oobi: "http://witness-demo:5647/oobi/BF2rZTW79z4IXocYRQnjjsOuvFUQv-ptCf8Yltd7PfsM/controller?name=wyz&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX",
//         alias: "wes",
//         oobi: "http://witness-demo:5644/oobi/BIKKuvBwpmDVA4Ds-EpL5bt9OqPzWPja2LigFYZN2YfX/controller?name=wes&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP",
//         alias: "wub",
//         oobi: "http://witness-demo:5646/oobi/BIj15u5V11bkbtAxMA7gcNJZcax-7TgaBMLsQnMHpYHP/controller?name=wub&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM",
//         alias: "wil",
//         oobi: "http://witness-demo:5643/oobi/BLskRTInXnMxWaGqcpSyMgo0nYbalW99cGZESrz3zapM/controller?name=wil&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE",
//         alias: "wit",
//         oobi: "http://witness-demo:5645/oobi/BM35JN8XeJSEfpxopjn5jr7tAHCE5749f0OobhMLCorE/controller?name=wit&tag=witness&tag=sample",
//         ends: { controller: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//         alias: "gleif",
//         oobi: "http://keria:3902/oobi/EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt/agent/EGBHjS_qPLWfHqv4n-FvhTZNzhYElWo0_Kb4nA1-bAIZ",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         alias: "qvi",
//         oobi: "http://keria:3902/oobi/EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL/agent/EK9zEekpdAcmat9PcP9O3u4lko_zvL_3eX7CnGULGFQq",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       },
//       {
//         id: "ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8",
//         alias: "le",
//         oobi: "http://keria:3902/oobi/ENNyO6CeWKsorCv02OD_s7V1AXOvHkTHTS5-Bqm2K5N8/agent/EHwO26PQi_-aSF95WLO_12JltCZrvxC0q4HoOPFgZ3MW",
//         ends: { agent: [Object], witness: [Object] },
//         challenges: [],
//         wellKnowns: []
//       }
//     ]
//   }
// ]

// %% [markdown]
// ## Credential Issuance Chain
// The test follows the official vLEI ecosystem hierarchy:
//
// - QVI Credential: GLEIF issues a Qualified vLEI Issuer credential to the QVI
// - LE Credential: QVI issues a Legal Entity credential to the LE
// - ECR Credential (Path 1): LE directly issues an Engagement Context Role credential to the Role holder
// - ECR AUTH Credential: LE issues an ECR authorization credential to the QVI
// - ECR Credential (Path 2): QVI issues another ECR credential using the AUTH credential
// - OOR AUTH Credential: LE issues an Official Organizational Role authorization to QVI
// - OOR Credential: QVI issues the final OOR credential to the Role holder

// %% [markdown]
// ### QVI Credential: GLEIF issues a Qualified vLEI Issuer credential to the QVI

// %%
// QVI LEI (Arbitrary value)
const qviData = {
    LEI: '254900OPPU84GM83MG36',
};

// GLEIF - Issue credential
const { credentialSaid: credentialSaid} = await issueCredential(
    gleifClient, 
    gleifAlias, 
    gleifRegistrySaid, 
    QVI_SCHEMA_SAID,
    qviAid.i,
    qviData
)

// GLEIF - get credential
const qviCredential = await gleifClient.credentials().get(credentialSaid);

// GLEIF - Ipex grant
const grantResponse = await ipexGrantCredential(
    gleifClient,
    gleifAlias, 
    qviAid.i,
    qviCredential
)

// QVI - Wait for grant notification
const grantNotifications = await waitForAndGetNotification(qviClient, IPEX_GRANT_ROUTE)
const grantNotification = grantNotifications[0]

// QVI - Admit Grant
const admitResponse = await ipexAdmitGrant(
    qviClient,
    qviAlias,
    gleifAid.i,
    grantNotification.a.d
)

// QVI - Mark notification
await markNotificationRead(qviClient, grantNotification.i)

// GLEIF - Wait for admit notification
const admitNotifications = await waitForAndGetNotification(gleifClient, IPEX_ADMIT_ROUTE)
const admitNotification = admitNotifications[0]

// GLEIF - Mark notification
await markNotificationRead(gleifClient, admitNotification.i)
// Out:
// Issuing credential from AID "gleif" to AID "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL"...
// Successfully created credential registry: EHki4Cf6HC531_tSF0WIq6jnflA-KIYSjKfojXjdz0xr
// Successfully created credential registry: EHNMTVq73qITp7Lel9xnrnSXTTO7sqbg0bnuVDGUC6A_
// {
//   name: "credential.EDxncvoJeDc9U_7D32kpdqggPrJJvkl7vZd-xmUJIOwL",
//   metadata: {
//     ced: {
//       v: "ACDC10JSON000197_",
//       d: "EDxncvoJeDc9U_7D32kpdqggPrJJvkl7vZd-xmUJIOwL",
//       i: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//       ri: "EAkkDRthKw0cPvMvFbMI_hpRiqL2Qp5kBMGsRvyT_dav",
//       s: "EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao",
//       a: {
//         d: "EMtgXcPNp8ymdrqWxsx54f1J5uOvI7jFYmAGEVMwy4T1",
//         i: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         LEI: "254900OPPU84GM83MG36",
//         dt: "2025-06-12T21:58:58.015000+00:00"
//       }
//     },
//     depends: {
//       name: "witness.EDEQ-rwst4cXjwX7UP0LCqWny1Dt_C8da9FBNEnA6tBf",
//       metadata: { pre: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt", sn: 2 },
//       done: false,
//       error: null,
//       response: null
//     }
//   },
//   done: true,
//   error: null,
//   response: {
//     ced: {
//       v: "ACDC10JSON000197_",
//       d: "EDxncvoJeDc9U_7D32kpdqggPrJJvkl7vZd-xmUJIOwL",
//       i: "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt",
//       ri: "EAkkDRthKw0cPvMvFbMI_hpRiqL2Qp5kBMGsRvyT_dav",
//       s: "EBfdlu8R27Fbx-ehrqwImnK-8Cm79sqbAQ4MmvEAYqao",
//       a: {
//         d: "EMtgXcPNp8ymdrqWxsx54f1J5uOvI7jFYmAGEVMwy4T1",
//         i: "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL",
//         LEI: "254900OPPU84GM83MG36",
//         dt: "2025-06-12T21:58:58.015000+00:00"
//       }
//     }
//   }
// }
// Successfully issued credential with SAID: EDxncvoJeDc9U_7D32kpdqggPrJJvkl7vZd-xmUJIOwL
// AID "gleif" granting credential to AID "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL" via IPEX...
// Successfully submitted IPEX grant from "gleif" to "EGzk7s5KZaKvTdhsofGPfwlHq3WWcCTNB6cdCNTeceFL".
// Waiting for notification with route "/exn/ipex/grant"...
// [Retry] Grant notification not found on attempt #1 of 5
// [Retry] Waiting 5000ms before next attempt...
// AID "qvi" admitting IPEX grant "EAHRNWYJMp925x9RWyGlSFP9sFkIp9jgjDFfLwDGNYZ4" from AID "EBXH9BX9G-ohOpzhlKfBzzAht-35g9DxRDgDwEnIy2Lt"...
// Successfully submitted IPEX admit for grant "EAHRNWYJMp925x9RWyGlSFP9sFkIp9jgjDFfLwDGNYZ4".
// Marking notification "0AC3AxXah_D760z9efWfCPzY" as read...
// Notification "0AC3AxXah_D760z9efWfCPzY" marked as read.
// Waiting for notification with route "/exn/ipex/admit"...
// Marking notification "0AAYR7ETpMR5grz0UrWwUl4I" as read...
// Notification "0AAYR7ETpMR5grz0UrWwUl4I" marked as read.

// %% [markdown]
// ### LE Credential: QVI issues a Legal Entity credential to the LE

// %%
// qvi - Issue credential
const { credentialSaid: credentialSaid} = await issueCredential(
    qviClient, 
    qviAlias, 
    qviRegistrySaid, 
    LE_SCHEMA_SAID,
    LEAid.i,
    LEData
)

// qvi - get credential (with all its data)
const credential = await qviClient.credentials().get(credentialSaid);

// qvi - Ipex grant
const grantResponse = await ipexGrantCredential(
    qviClient,
    qviAlias, 
    LEAid.i,
    credential
)

// LE - Wait for grant notification
const grantNotifications = await waitForAndGetNotification(LEClient, IPEX_GRANT_ROUTE)
const grantNotification = grantNotifications[0]

// LE - Admit Grant
const admitResponse = await ipexAdmitGrant(
    LEClient,
    LEAlias,
    qviAid.i,
    grantNotification.a.d
)

// LE - Mark notification
await markNotificationRead(LEClient, grantNotification.i)

// qvi - Wait for admit notification
const admitNotifications = await waitForAndGetNotification(qviClient, IPEX_ADMIT_ROUTE)
const admitNotification = admitNotifications[0]

// qvi - Mark notification
await markNotificationRead(qviClient, admitNotification.i)

// %% [markdown]
// ### ECR Credential (Path 1): LE directly issues an Engagement Context Role credential to the Role holder

// %% [markdown]
// ### ECR AUTH Credential: LE issues an ECR authorization credential to the QVI

// %% [markdown]
// ### ECR Credential (Path 2): QVI issues another ECR credential using the AUTH credential

// %% [markdown]
// ### OOR AUTH Credential: LE issues an Official Organizational Role authorization to QVI

// %% [markdown]
// ### OOR Credential: QVI issues the final OOR credential to the Role holder

// %% [markdown]
// Summary:
//
// Hierarchical trust: Each credential references its authorizing credential
// Multiple issuance paths: Shows both direct issuance (LE→Role) and authorized issuance (LE→QVI→Role)
// IPEX protocol: Uses grant/admit message exchange for credential delivery
// Schema compliance: Each credential follows specific vLEI schemas
// Credential chaining: Later credentials reference earlier ones as sources of authority
// This represents a simplified vLEI ecosystem where organizations can issue verifiable credentials about legal entities and their roles while maintaining a proper chain of trust.
