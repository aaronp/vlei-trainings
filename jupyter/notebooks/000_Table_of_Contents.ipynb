# %% [markdown]
# # Table of Contents
# ## 101 Basics KLI
# 1. [Welcome to vLEI Training - 101](101_05_Welcome_to_vLEI_Training_-_101.ipynb#Welcome-to-vLEI-Training---101)
#     1. [Prerequisites](101_05_Welcome_to_vLEI_Training_-_101.ipynb#Prerequisites)
#     1. [Versions](101_05_Welcome_to_vLEI_Training_-_101.ipynb#Versions)
# 1. [Introduction to KERI, ACDC, and vLEI](101_07_Introduction_to-KERI_ACDC_and_vLEI.ipynb#Introduction-to-KERI-ACDC-and-vLEI)
#     1. [The KERI Protocol](101_07_Introduction_to-KERI_ACDC_and_vLEI.ipynb#The-KERI-Protocol)
#     1. [The ACDC Protocol](101_07_Introduction_to-KERI_ACDC_and_vLEI.ipynb#The-ACDC-Protocol)
#     1. [GLEIF vLEI Ecosystem](101_07_Introduction_to-KERI_ACDC_and_vLEI.ipynb#GLEIF-vLEI-Ecosystem)
# 1. [KERI Command Line Interface](101_10_KERI_Command_Line_Interface.ipynb#KERI-Command-Line-Interface)
#     1. [How to use KLI in Notebooks?](101_10_KERI_Command_Line_Interface.ipynb#How-to-use-KLI-in-Notebooks)
#     1. [Basic Utility Commands](101_10_KERI_Command_Line_Interface.ipynb#Basic-Utility-Commands)
# 1. [Controllers and Identifiers](101_15_Controllers_and_Identifiers.ipynb#Controllers-and-Identifiers)
#     1. [What is an Identifier?](101_15_Controllers_and_Identifiers.ipynb#What-is-an-Identifier)
#     1. [What is a Controller?](101_15_Controllers_and_Identifiers.ipynb#What-is-a-Controller)
#     1. [The Key Event Log](101_15_Controllers_and_Identifiers.ipynb#The-Key-Event-Log)
#     1. [Advanced Forms of Control](101_15_Controllers_and_Identifiers.ipynb#Advanced-Forms-of-Control)
# 1. [Working with Keystores and AIDs via KLI](101_20_Working_with_Keystores_and_AIDs_via_KLI.ipynb#Working-with-Keystores-and-AIDs-via-KLI)
#     1. [Initializing a Keystore](101_20_Working_with_Keystores_and_AIDs_via_KLI.ipynb#Initializing-a-Keystore)
#     1. [Creating an Identifier](101_20_Working_with_Keystores_and_AIDs_via_KLI.ipynb#Creating-an-Identifier)
#     1. [The Prefix](101_20_Working_with_Keystores_and_AIDs_via_KLI.ipynb#The-Prefix)
#     1. [Displaying the Identifier](101_20_Working_with_Keystores_and_AIDs_via_KLI.ipynb#Displaying-the-Identifier)
#     1. [Displaying the KEL](101_20_Working_with_Keystores_and_AIDs_via_KLI.ipynb#Displaying-the-KEL)
#     1. [Displaying the keystore Identifiers](101_20_Working_with_Keystores_and_AIDs_via_KLI.ipynb#Displaying-the-keystore-Identifiers)
# 1. [Signatures](101_25_Signatures.ipynb#Signatures)
#     1. [What is a Digital Signature?](101_25_Signatures.ipynb#What-is-a-Digital-Signature)
#     1. [Signatures and Verification](101_25_Signatures.ipynb#Signatures-and-Verification)
#     1. [Signing and Verifying with KLI](101_25_Signatures.ipynb#Signing-and-Verifying-with-KLI)
# 1. [Key Rotation and Pre-rotation](101_30_Key_Rotation.ipynb#Key-Rotation-and-Pre-rotation)
#     1. [Why is Key Rotation Important?](101_30_Key_Rotation.ipynb#Why-is-Key-Rotation-Important)
#     1. [Establishment Events](101_30_Key_Rotation.ipynb#Establishment-Events)
#     1. [Pre-Rotation](101_30_Key_Rotation.ipynb#Pre-Rotation)
#     1. [Key rotation with KLI](101_30_Key_Rotation.ipynb#Key-rotation-with-KLI)
# 1. [Modes, OOBIs, and Witnesses](101_35_Modes_oobis_and_witnesses.ipynb#Modes-OOBIs-and-Witnesses)
#     1. [Direct and Indirect Modes](101_35_Modes_oobis_and_witnesses.ipynb#Direct-and-Indirect-Modes)
#     1. [Out-of-Band Introductions](101_35_Modes_oobis_and_witnesses.ipynb#Out-of-Band-Introductions)
#     1. [Witnesses](101_35_Modes_oobis_and_witnesses.ipynb#Witnesses)
#     1. [Threshold of Accountable Duplicity](101_35_Modes_oobis_and_witnesses.ipynb#Threshold-of-Accountable-Duplicity)
# 1. [Witnesses](101_40_Witnesses.ipynb#Witnesses)
#     1. [Witness network](101_40_Witnesses.ipynb#Witness-network)
#     1. [Initializing a keystore](101_40_Witnesses.ipynb#Initializing-a-keystore)
#     1. [Listing keystore contacts](101_40_Witnesses.ipynb#Listing-keystore-contacts)
#     1. [Creating an AID](101_40_Witnesses.ipynb#Creating-an-AID)
# 1. [Connecting controllers](101_45_Connecting_controllers.ipynb#Connecting-controllers)
#     1. [Controllers setup](101_45_Connecting_controllers.ipynb#Controllers-setup)
#     1. [OOBI setup](101_45_Connecting_controllers.ipynb#OOBI-setup)
#     1. [Challenge-response](101_45_Connecting_controllers.ipynb#Challenge-response)
# 1. [Introduction to ACDCs](101_50_ACDC.ipynb#Introduction-to-ACDCs)
#     1. [What is an ACDC?](101_50_ACDC.ipynb#What-is-an-ACDC)
#     1. [Self-Addressing Identifiers](101_50_ACDC.ipynb#Self-Addressing-Identifiers)
#     1. [Structure of an ACDC](101_50_ACDC.ipynb#Structure-of-an-ACDC)
#     1. [ACDCs Security and Verifiability](101_50_ACDC.ipynb#ACDCs-Security-and-Verifiability)
# 1. [ACDC Schemas](101_55_Schemas.ipynb#ACDC-Schemas)
#     1. [What is a Schema?](101_55_Schemas.ipynb#What-is-a-Schema)
#     1. [Writing ACDC Schemas](101_55_Schemas.ipynb#Writing-ACDC-Schemas)
# 1. [Saidifying](101_60_Saidify_schema.ipynb#Saidifying)
#     1. [Schema SAIDs](101_60_Saidify_schema.ipynb#Schema-SAIDs)
#     1. [SAIDifying a Schema](101_60_Saidify_schema.ipynb#SAIDifying-a-Schema)
#     1. [Caching Schemas](101_60_Saidify_schema.ipynb#Caching-Schemas)
# 1. [ACDC Issuance](101_65_ACDC_Issuance.ipynb#ACDC-Issuance)
#     1. [Setting up Holder and Issuer](101_65_ACDC_Issuance.ipynb#Setting-up-Holder-and-Issuer)
#     1. [Schema preparation](101_65_ACDC_Issuance.ipynb#Schema-preparation)
#     1. [Prepare and Create Credential](101_65_ACDC_Issuance.ipynb#Prepare-and-Create-Credential)
#     1. [IPEX Credential Issuance Flow](101_65_ACDC_Issuance.ipynb#IPEX-Credential-Issuance-Flow)
# 1. [ACDC Presentation and Rovocation](101_70_ACDC_Presentation_and_Revocation.ipynb#ACDC-Presentation-and-Rovocation)
#     1. [IPEX Credential Presentation](101_70_ACDC_Presentation_and_Revocation.ipynb#IPEX-Credential-Presentation)
#     1. [Credential Presentation Flow](101_70_ACDC_Presentation_and_Revocation.ipynb#Credential-Presentation-Flow)
#     1. [Credential revocation](101_70_ACDC_Presentation_and_Revocation.ipynb#Credential-revocation)
# 1. [ACDC Edges and Rules](101_75_ACDC_Edges_and_Rules.ipynb#ACDC-Edges-and-Rules)
#     1. [Edges, Edge Operators and Rules](101_75_ACDC_Edges_and_Rules.ipynb#Edges-Edge-Operators-and-Rules)
#     1. [I2I (Issuer-To-Issuee)](101_75_ACDC_Edges_and_Rules.ipynb#I2I-Issuer-To-Issuee)
#     1. [NI2I (Not-Issuer-To-Issuee)](101_75_ACDC_Edges_and_Rules.ipynb#NI2I-Not-Issuer-To-Issuee)
#     1. [DI2I (Delegated-Issuer-To-Issuee)](101_75_ACDC_Edges_and_Rules.ipynb#DI2I-Delegated-Issuer-To-Issuee)
#
# ## 102 Basics Keria-Signify
# 1. [SignifyTS - Keria Basics](102_05_Keria_Signify.ipynb#SignifyTS---Keria-Basics)
#     1. [Keria/Signify Architecture Overview](102_05_Keria_Signify.ipynb#KeriaSignify-Architecture-Overview)
#     1. [Keria Service Endpoint Interfaces](102_05_Keria_Signify.ipynb#Keria-Service-Endpoint-Interfaces)
#     1. [End Roles](102_05_Keria_Signify.ipynb#End-Roles)
#     1. [Client AID and Agent AID](102_05_Keria_Signify.ipynb#Client-AID-and-Agent-AID)
# 1. [SignifyTS - Keria Basic Operations](102_10_Keria_Signify_Basic_Operations.ipynb#SignifyTS---Keria-Basic-Operations)
#     1. [Create a Client and Connect to the Keria Agent](102_10_Keria_Signify_Basic_Operations.ipynb#Create-a-Client-and-Connect-to-the-Keria-Agent)
#     1. [Reconnecting to an Existing Agent](102_10_Keria_Signify_Basic_Operations.ipynb#Reconnecting-to-an-Existing-Agent)
#     1. [Add an Autonomic Identifier (AID)](102_10_Keria_Signify_Basic_Operations.ipynb#Add-an-Autonomic-Identifier-AID)
#     1. [Managing Operations](102_10_Keria_Signify_Basic_Operations.ipynb#Managing-Operations)
# 1. [Keria-Signify Connecting Controllers](102_15_Keria_Signify_Connecting_Clients.ipynb#Keria-Signify-Connecting-Controllers)
#     1. [Controllers Setup](102_15_Keria_Signify_Connecting_Clients.ipynb#Controllers-Setup)
#     1. [End Roles](102_15_Keria_Signify_Connecting_Clients.ipynb#End-Roles)
#     1. [OOBI Setup](102_15_Keria_Signify_Connecting_Clients.ipynb#OOBI-Setup)
#     1. [Challenge-Response](102_15_Keria_Signify_Connecting_Clients.ipynb#Challenge-Response)
